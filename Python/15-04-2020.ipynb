# %%
## Pandas
### Dataframes
import pandas as pd
data1 = {'s1':25,'s2':48,'s3':54}
data1 = pd.Series(data1)
data2 = {'s1':52,'s2':84,'s3':45}
data2 = pd.Series(data2)
print(data1,"\n",data2)
# Out:
# s1    25
# s2    48
# s3    54
# dtype: int64
#  s1    52
# s2    84
# s3    45
# dtype: int64

# %%
result = {'Data':data1,'Data1':data2}
result = pd.DataFrame(result)
result
# Out:
#     Data  Data1
# s1    25     52
# s2    48     84
# s3    54     45

# %%
df = pd.DataFrame({'name':['Chiru','Ram'],'age':[66,30],'occupation':['Actor','Doctor']})
df
# Out:
#     name  age occupation
# 0  Chiru   66      Actor
# 1    Ram   30     Doctor

# %%
coronadf = pd.read_csv('us.csv')
coronadf
# Out:
#              date       county       state     fips  cases  deaths
# 0      2020-01-21    Snohomish  Washington  53061.0      1       0
# 1      2020-01-22    Snohomish  Washington  53061.0      1       0
# 2      2020-01-23    Snohomish  Washington  53061.0      1       0
# 3      2020-01-24         Cook    Illinois  17031.0      1       0
# 4      2020-01-24    Snohomish  Washington  53061.0      1       0
# 5      2020-01-25       Orange  California   6059.0      1       0
# 6      2020-01-25         Cook    Illinois  17031.0      1       0
# 7      2020-01-25    Snohomish  Washington  53061.0      1       0
# 8      2020-01-26     Maricopa     Arizona   4013.0      1       0
# 9      2020-01-26  Los Angeles  California   6037.0      1       0
# 10     2020-01-26       Orange  California   6059.0      1       0
# 11     2020-01-26         Cook    Illinois  17031.0      1       0
# 12     2020-01-26    Snohomish  Washington  53061.0      1       0
# ...

# %%
coronadf.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
coronadf.tail(3)
# Out:
#              date    county    state     fips  cases  deaths
# 53845  2020-04-12     Teton  Wyoming  56039.0     56       0
# 53846  2020-04-12     Uinta  Wyoming  56041.0      4       0
# 53847  2020-04-12  Washakie  Wyoming  56043.0      4       0

# %%
coronadf.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
coronadf['state'].value_counts()
# Out:
# Georgia                     3182
# Texas                       3134
# Virginia                    2205
# Indiana                     1868
# North Carolina              1855
# Tennessee                   1813
# California                  1778
# Mississippi                 1756
# Ohio                        1706
# Kentucky                    1633
# Florida                     1625
# Michigan                    1549
# New York                    1548
# Missouri                    1525
# Illinois                    1511
# Pennsylvania                1456
# Louisiana                   1436
# Iowa                        1383
# Arkansas                    1338
# Alabama                     1329
# Minnesota                   1303
# Colorado                    1303
# Wisconsin                   1257
# Washington                  1131
# Oklahoma                    1106
# South Carolina              1082
# Kansas                       999
# Oregon                       727
# ...

# %%
coronadf.nunique()
# Out:
# date        83
# county    1608
# state       55
# fips      2667
# cases     1578
# deaths     264
# dtype: int64

# %%
coronadf.describe()
# Out:
#                fips          cases        deaths
# count  53132.000000   53848.000000  53848.000000
# mean   29529.152036     106.149328      3.178985
# std    15549.107764    1336.965313     65.751445
# min     1001.000000       0.000000      0.000000
# 25%    17161.000000       2.000000      0.000000
# 50%    28135.000000       5.000000      0.000000
# 75%    42125.000000      22.000000      1.000000
# max    56043.000000  103208.000000   6717.000000

# %%
len(coronadf)
# Out:
# 53848

# %%
coronadf.shape
# Out:
# (53848, 6)

# %%
coronadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53848 entries, 0 to 53847
# Data columns (total 6 columns):
# date      53848 non-null object
# county    53848 non-null object
# state     53848 non-null object
# fips      53132 non-null float64
# cases     53848 non-null int64
# deaths    53848 non-null int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.5+ MB

# %%
coronadf.loc[coronadf["state"]=="Wyoming"]
# Out:
#              date       county    state     fips  cases  deaths
# 1363   2020-03-11     Sheridan  Wyoming  56033.0      1       0
# 1618   2020-03-12     Sheridan  Wyoming  56033.0      1       0
# 1932   2020-03-13      Fremont  Wyoming  56013.0      1       0
# 1933   2020-03-13     Sheridan  Wyoming  56033.0      1       0
# 2307   2020-03-14      Fremont  Wyoming  56013.0      1       0
# 2308   2020-03-14     Sheridan  Wyoming  56033.0      2       0
# 2736   2020-03-15      Fremont  Wyoming  56013.0      1       0
# 2737   2020-03-15     Sheridan  Wyoming  56033.0      2       0
# 3212   2020-03-16      Fremont  Wyoming  56013.0      8       0
# 3213   2020-03-16     Sheridan  Wyoming  56033.0      2       0
# 3756   2020-03-17      Fremont  Wyoming  56013.0      8       0
# 3757   2020-03-17      Laramie  Wyoming  56021.0      2       0
# 3758   2020-03-17         Park  Wyoming  56029.0      1       0
# 3759   2020-03-17     Sheridan  Wyoming  56033.0      4       0
# ...

# %%
coronadf.loc[coronadf["state"]=="Wyoming","date"]
# Out:
# 1363     2020-03-11
# 1618     2020-03-12
# 1932     2020-03-13
# 1933     2020-03-13
# 2307     2020-03-14
# 2308     2020-03-14
# 2736     2020-03-15
# 2737     2020-03-15
# 3212     2020-03-16
# 3213     2020-03-16
# 3756     2020-03-17
# 3757     2020-03-17
# 3758     2020-03-17
# 3759     2020-03-17
# 4395     2020-03-18
# 4396     2020-03-18
# 4397     2020-03-18
# 4398     2020-03-18
# 4399     2020-03-18
# 5161     2020-03-19
# 5162     2020-03-19
# 5163     2020-03-19
# 5164     2020-03-19
# 5165     2020-03-19
# 6075     2020-03-20
# 6076     2020-03-20
# 6077     2020-03-20
# 6078     2020-03-20
# 6079     2020-03-20
# 6080     2020-03-20
#             ...
# 51160    2020-04-11
# 51161    2020-04-11
# 51162    2020-04-11
# 51163    2020-04-11
# 51164    2020-04-11
# 51165    2020-04-11
# 51166    2020-04-11
# 51167    2020-04-11
# 51168    2020-04-11
# 53827    2020-04-12
# 53828    2020-04-12
# 53829    2020-04-12
# 53830    2020-04-12
# 53831    2020-04-12
# ...

# %%
coronadf.iloc[0:10]
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1       0
# 1  2020-01-22    Snohomish  Washington  53061.0      1       0
# 2  2020-01-23    Snohomish  Washington  53061.0      1       0
# 3  2020-01-24         Cook    Illinois  17031.0      1       0
# 4  2020-01-24    Snohomish  Washington  53061.0      1       0
# 5  2020-01-25       Orange  California   6059.0      1       0
# 6  2020-01-25         Cook    Illinois  17031.0      1       0
# 7  2020-01-25    Snohomish  Washington  53061.0      1       0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1       0
# 9  2020-01-26  Los Angeles  California   6037.0      1       0

# %%
coronadf.dtypes
# Out:
# date       object
# county     object
# state      object
# fips      float64
# cases       int64
# deaths      int64
# dtype: object

# %%
coronadf.index
# Out:
# RangeIndex(start=0, stop=53848, step=1)

# %%
coronadf.values
# Out:
# array([['2020-01-21', 'Snohomish', 'Washington', 53061.0, 1, 0],
#        ['2020-01-22', 'Snohomish', 'Washington', 53061.0, 1, 0],
#        ['2020-01-23', 'Snohomish', 'Washington', 53061.0, 1, 0],
#        ...,
#        ['2020-04-12', 'Teton', 'Wyoming', 56039.0, 56, 0],
#        ['2020-04-12', 'Uinta', 'Wyoming', 56041.0, 4, 0],
#        ['2020-04-12', 'Washakie', 'Wyoming', 56043.0, 4, 0]], dtype=object)
