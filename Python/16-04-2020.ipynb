# %%
import pandas as pd
ad = pd.read_csv('androiddevices.csv')
uu = pd.read_csv('userusage.csv')
ud = pd.read_csv('userdevice.csv')
ad
# Out:
#                   Retail Branding                   Marketing Name  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                              3Q                          OC1020A
# 5                         7Eleven                            IN265
# 6      A.O.I. ELECTRONICS FACTORY                           A.O.I.
# 7                       AG Mobile                       AG BOOST 2
# 8                       AG Mobile                         AG Flair
# 9                       AG Mobile               AG Go Tab Access 2
# 10                      AG Mobile                        AG Ultra2
# 11                      AG Mobile                 AG_Go-Tab_Access
# 12                      AG Mobile                       AG_Tab_7_0
# ...

# %%
uu
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# 5                      71.59                   79.26     1557.33   22793
# 6                      71.59                   79.26      519.12   22794
# 7                      71.59                   79.26      519.12   22795
# 8                      30.92                   22.77     3114.67   22799
# 9                      69.80                   14.70    25955.55   22801
# 10                    554.41                  150.06     3114.67   22804
# 11                    189.10                   24.08      519.12   22805
# ...

# %%
ud
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# 5     22787    12921  android               4.3                GT-I9505
# 6     22788    28714  android               6.0                SM-G930F
# 7     22789    28714  android               6.0                SM-G930F
# 8     22790    29592  android               5.1                   D2303
# 9     22791    28775      ios              10.2               iPhone6,2
# 10    22792    28217  android               5.1                SM-G361F
# 11    22793    28217  android               5.1                SM-G361F
# ...

# %%
m = pd.merge(uu,ud,on='use_id')
m
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 2                    1710.08                  136.88     7267.55   22789
# 3                      94.46                   35.17      519.12   22790
# 4                      71.59                   79.26     1557.33   22792
# 5                      71.59                   79.26     1557.33   22793
# 6                      71.59                   79.26      519.12   22794
# 7                      71.59                   79.26      519.12   22795
# 8                      30.92                   22.77     3114.67   22799
# 9                      69.80                   14.70    25955.55   22801
# 10                    554.41                  150.06     3114.67   22804
# 11                    189.10                   24.08      519.12   22805
# ...

# %%
m.columns.value_counts()
# Out:
# outgoing_mins_per_month    1
# platform                   1
# user_id                    1
# platform_version           1
# use_type_id                1
# use_id                     1
# monthly_mb                 1
# outgoing_sms_per_month     1
# device                     1
# dtype: int64

# %%
m[['use_id','user_id']]
# Out:
#      use_id  user_id
# 0     22787    12921
# 1     22788    28714
# 2     22789    28714
# 3     22790    29592
# 4     22792    28217
# 5     22793    28217
# 6     22794    28217
# 7     22795    28217
# 8     22799    29643
# 9     22801    10976
# 10    22804    29645
# 11    22805    29646
# 12    22806    21615
# 13    22808    29065
# 14    22813    23415
# 15    22814    23415
# 16    22815    23415
# 17    22816    23415
# 18    22817    23415
# 19    22819    29651
# 20    22820    29651
# 21    22822    29651
# 22    22823    29652
# 23    22824    28953
# 24    22829    29653
# 25    22830    29065
# 26    22831     6541
# 27    22832    29295
# 28    22833    24847
# 29    22839    29655
# ..      ...      ...
# 242   22976    29699
# 243   22983    29445
# 244   22984    29445
# 245   22990    29703
# 246   22993    27965
# 247   22996    29319
# 248   23000    29703
# 249   23001    28898
# 250   23004    29708
# 251   23006    29709
# 252   23007    29710
# ...

# %%
m[['device','platform']]
# Out:
#              device platform
# 0          GT-I9505  android
# 1          SM-G930F  android
# 2          SM-G930F  android
# 3             D2303  android
# 4          SM-G361F  android
# 5          SM-G361F  android
# 6          SM-G361F  android
# 7          SM-G361F  android
# 8     ONEPLUS A3003  android
# 9          GT-I9505  android
# 10         SM-G935F  android
# 11         GT-I9195  android
# 12            A0001  android
# 13         SM-G900F  android
# 14   HTC Desire 510  android
# 15   HTC Desire 510  android
# 16   HTC Desire 510  android
# 17   HTC Desire 510  android
# 18   HTC Desire 510  android
# 19   HTC One mini 2  android
# 20   HTC One mini 2  android
# 21   HTC One mini 2  android
# 22         SM-G900F  android
# 23         SM-G900F  android
# 24        iPhone7,2      ios
# 25         SM-G900F  android
# 26        GT-I8190N  android
# 27            D5803  android
# 28            E6653  android
# 29            A0001  android
# ..              ...      ...
# ...

# %%
m.nunique()
# Out:
# outgoing_mins_per_month    123
# outgoing_sms_per_month     117
# monthly_mb                  35
# use_id                     272
# user_id                    172
# platform                     2
# platform_version            15
# device                      72
# use_type_id                  3
# dtype: int64

# %%
m.describe()
# Out:
#        outgoing_mins_per_month  outgoing_sms_per_month    monthly_mb  \
# count               159.000000              159.000000    159.000000
# mean                203.331509               87.978742   4180.378616
# std                 248.660581               92.386434   5216.463795
# min                   0.500000                0.250000      0.000000
# 25%                  70.070000               22.855000   1557.330000
# 50%                 137.060000               62.850000   2076.450000
# 75%                 241.035000              119.675000   5191.120000
# max                1710.080000              540.600000  31146.670000
#
#              use_id       user_id  platform_version  use_type_id
# count    272.000000    272.000000        272.000000   272.000000
# mean   22917.500000  26583.095588          6.917647     1.654412
# std       78.663842   5737.037885          2.144877     0.858031
# min    22782.000000   2873.000000          4.100000     1.000000
# ...
